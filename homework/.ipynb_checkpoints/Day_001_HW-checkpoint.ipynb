# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    計算MAE
    """
    mse = MSE = sum((y-yp)**2) / len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 211.068
# The Mean absolute error is 11.944

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 參考資料集: New York City Airbnb Open Data( Airbnb listings and metrics in NYC, NY, USA (2019) )
# 1. 你選的這組資料為何重要
#
# 此數據集可以知道甚麼樣的條件(租屋地點、日期、價格、附近地標、交通、人數)會影響消費者的租屋選擇。對於當地的民宿或是青年旅館、商旅是一個不錯的參考資源，透過分析這些資料可以得知消費者的對於住宿地點的喜好與接受價格分布。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 透過租屋平台Airbnb統計(所以這筆資料集只有使用Airbnb的客戶)，必須是完成交易手續的訂單。
#
# 3. 蒐集而來的資料型態為何
#
# 結構化資料:數值(價格、居住天數、人數...etc.)、字串(旅館位置、鄰近地標、日期)。
#
# 4. 這組資料想解決的問題如何評估
#
# 回歸問題:預測價格、禮拜一~日的check in頻率。指標:MAE、MSE、RMSE。
#
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 核心問題: 自由載客車隊競爭激烈，如何降低成本回饋顧客、價格透明化是很重要的。(價格透明不列入以下考慮)
# a. 根據蒐集的數據集得知何處的顧客較多，可以安排較多的計程車在附近待命(減少顧客等車時間、減少耗油)。
# b. 藉由提供部分優惠來吸引客群(優惠券、會員制)，成效結果也可由蒐集的數據得知。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 有平台(app、web端):訂單需要有金額、里程、叫車地點、日期、從叫車到顧客上車所花費的時間、上車到下車所費時間。
#
# 3. 蒐集而來的資料型態為何
#
# 數據: 金額、里程、從叫車到顧客上車所花費的時間、上車到下車所費時間。
# 字串: 叫車地點、日期。
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# 回歸問題: 價格預測、完成載客所費時間、計程車到達叫車地點所費時間預測。這三個問題對於顧客來說是很重要的參考數據，如果能使用app事先知道，對於乘客對於乘客來說，可以更容易掌握時程的規劃，進而減少消費糾紛，也可以使顧客對於本載客車隊服務更有信賴感，進而增加消費次數。
