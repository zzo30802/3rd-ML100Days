# %% [markdown]
# # D63：神經網路介紹

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 重點目標
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 教學

# %% [markdown]
# ### 機器學習與深度學習介紹
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 機器學習與深度學習比較
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 深度學習歷史
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 深度學習應用爆發的三大關鍵
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 類神經網路 (Neural Network)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 類神經網路與深度學習的比較
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 深度學習 - 巨觀結構
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 神經網路架構示意圖介紹
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 神經網路架構介紹
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 深度學習 - 微觀結構
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 神經元結構
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 神經網路實務應用-卷積神經網路 (CNN, Convolutional Neural Network)
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 神經網路實務應用-遞歸神經網路 (RNN, Recurrent Neural Network
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 重點複習
# ![image.png](attachment:image.png)

# %% [raw]
# 神經網路參考影片

# %% [markdown]
# Machine Learning VS Deep Learning: [Whats The Difference] (作者: vishal kalia)
# https://www.youtube.com/watch?v=LhVY0-S7cAM
#
# Deep Learning In 5 Minutes | What Is Deep Learning? | Deep Learning Explained Simply | Simplilearn(作者: Simplilearn)
# https://www.youtube.com/watch?v=6M5VXKLf4D4
#
# 深度學習基本概念(作者:中國大學MOOC-慕課)
# https://www.youtube.com/watch?v=TrhwJQ12EN4
#
# 人工神經網路 VS 生物神經網路(作者:周莫煩)
# https://www.youtube.com/watch?v=lAaCeiqE6CE

# %% [markdown]
# ## 延伸閱讀
# ![image.png](attachment:image.png)

# %% [raw]
# https://medium.com/@suipichen/%E4%BA%BA%E5%B7%A5%E6%99%BA%E6%85%A7%E5%A4%A7%E6%AD%B7%E5%8F%B2-ffe46a350543

# %% [markdown]
# ## 作業

# %% [raw]
# 在精簡深度學習的方式上 : 卷積類神經 (CNN) 採用像素遠近，而遞歸類神經 (RNN) 採用著則是時間遠近
# 那麼，既然有著類似的設計精神，兩者是否有可能互換應用呢?

# %% [markdown]
# # D64：深度學習體驗 : 模型調整與學習曲線
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 目標
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 教學

# %% [markdown]
# ### 深度學習體驗平台：TensorFlowPlayGround

# %% [markdown]
# https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=circle&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=4,2&seed=0.20748&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### TF PlayGround 平台介面說明

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 平台上的資料集
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 練習 1：按下啟動，觀察指標變化
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 練習 2：增減隱藏層數
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 練習 3：增減神經元數
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 練習 4：切換不同特徵
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 重點複習
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 延伸閱讀

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://pairlabs.ai/tensorflow-playground/index_tw.html#activation=tanh&batchSize=10&dataset=circle&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=4,2&seed=0.81970&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false

# %% [markdown]
# ## 作業

# %% [raw]
# 選擇迴歸資料集(右) - 交錯六群，在其他參數保持預設值的情況下，只允許調整隱藏層層數與神經元數量，且遵守下列限制：
#
#
#
# 隱藏層神經元總數最多 8 個 (即 : 可以單層 8 個，或兩層 5 個與 3 個)
#
# 遞迴次數只允許跑到 500 次
#
#
#
# 作業：在上述限制下，挑戰看看測試誤差 (Test Loss) 最低能到多少? 請回答你的神經元參數與 Test Loss 數

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # D65：深度學習體驗 : 啟動函數與正規化

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 重點
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 練習 5：切換批次⼤大⼩小

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 練習 6：切換學習速率

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 練習 7：切換啟動函數

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 練習８：切換正規化選項與參參數

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 重點
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 延伸閱讀

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://cloud.google.com/blog/products/gcp/understanding-neural-networks-with-tensorflow-playground

# %% [markdown]
# 深度深度學習網路路調參參技巧 with TensorFlow Playground 知乎
# ![image.png](attachment:image.png)

# %% [markdown]
# https://zhuanlan.zhihu.com/p/24720954

# %% [markdown]
# ## 作業

# %% [raw]
# 作業
# 選擇分類資料集(右下)-螺旋雙臂 - 交錯六群，限定特徵只能使用前兩個，隱藏層 2 層滿 (共 8 * 2 =16 個神經元)，
# 遞迴次數只允許跑到500次，但可以自由調整 批次大小、學習速率、啟動函數、正規化選項與參數
# 在上述限制下，挑戰看看測試誤差 (Test Loss) 最低能到多少? 請回答你的上述幾項參數與 Test Loss 數
