# %% [markdown]
# # 資料結構導論

# %% [markdown]
# ## 資料的特性

# %% [raw]
# 依據資料在計算機程式語言中的存在層次來區分，可以分為以下三種型態：
# 1. 基本資料型態(Primitive Data Type): int, float, char
# 2. 結構化資料型態(Structured Data Type): string, array, pointer, list, file
# 3. 抽象資料型態(Abstract Data Type, ADT): 對一種資料型態而言，可以將其看成是一種值得集合，以及在這些值上所做的運算與本身所代表的意義便是定義這種資料型態所具備的數學關係。Stack (Last in First out)

# %% [markdown]
# ## 演算法

# %% [raw]
# 演算法：程式是否能清楚而正確的把問題解決。
# 資料結構：程式能否快速而有效率的完成預定的任務。
#
# Algorithm + Data structure = 可執行程式

# %% [markdown]
# ### 演算法的條件

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# 常用演算法:
# 1. 一般文字敘述
# 2. 虛擬語言(Pseudo-Language)
# 3. 表格或圖形: 陣列、樹狀圖、矩陣圖
# 4. 流程圖(Flow Diagram)
# 5. 程序語言: C++, C, Java

# %% [markdown]
# ## 認識程式語言

# %% [markdown]
# ### 程式開發流程

# %% [raw]
# 評斷程式語言好壞的要素如下：
# 1. 可讀性(Readability): 閱讀與理解相當容易。
# 2. 平均成本低: 成本考量不侷限於編譯的成本，還包括執行、編譯、維護、學習、除錯與日後更新成本。
# 3. 可靠度高: 不容易產生邊際錯誤(Side Effect)
# 4. 可撰寫性高: 對於針對需求所撰寫的程式相對容易。

# %% [raw]
# 程式產生過程:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 結構化程式設計

# %% [raw]
# 結構化程式設計的核心精神: 「由上而下設計」、「模組化設計」

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 物件導向程式設計
# OOP能夠使更生活化、可讀性更高的設計觀念來進行，所開發出的程式也較容易擴充、修改、維護。

# %% [raw]
# OOP的重點:
# 1. 可讀性(Readability)
# 2. 重複使用性(Reusability)
# 3. 延伸性(Extension)
#
# OOP的特性:
# 1. 封裝性(Encapsulation)
# 2. 繼承性(Inheritance)
# 3. 多形性(Polymorpgism)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 封裝

# %% [raw]
# 封裝是利用class來實作抽象化資料型態(ADT)。
# 可以看成是一個模型or藍圖，按照這個模型or藍圖所產生出來的實體(Instance)，就被稱為物件。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# 抽象化: 將代表事物特徵的資料隱藏起來，並定義「方法」(method)做為操作這些資料的介面，讓使用者只能接觸到這些方法，而無法直接使用資料，符合了「資料隱藏」(Information Hiding)的意義，這種自訂的資料型態就稱為「抽象化資料型態」。相對於傳統程式設計理念，就必須掌握所有的來龍去脈，針對時效性而言，便大大地打了折扣。

# %% [markdown]
# #### 繼承

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 多形

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 演算法效能分析

# %% [markdown]
# ### 空間複雜度

# %% [raw]
# 記憶體空間分成兩種
# 1. 固定空間記憶體(包括基本程式碼、常數、變數)
# 2. 變動空間記憶體(隨程式or進行時而改變大小的使用空間，ex:參考形變數)

# %% [markdown]
# ### 時間複雜度

# %% [raw]
# 變數儲存型態、運算式的複雜度，所以真正絕對精度的執行時間一定不相同。

# %% [raw]
# 在一個完全理想狀態下的計算機中，我們定義一個T(n)來表示程式執行所要花費的時間，其中n代表資料輸入量。
#
# 當然程式的執行時間or最大執行時間(Worse Case Executing Time)作為時間複雜度的衡量標準，一般以Big-oh表示。

# %% [raw]
# 由於分析演算法的時間複雜度必須考慮它的成長比率(Rate of Growth)往往是一個函數，而時間複雜度本身也是一種「漸近表示」(Asymptotic Notation)。

# %% [markdown]
# ### Big-oh

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 常見Big-oh

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### omega

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### theta

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 陣列結構

# %% [markdown]
# 線性串列(Linear List)定義：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 常見8種運算方式：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 儲存結構簡介

# %% [markdown]
# ### 靜態資料結構

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 動態資料結構

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 認識陣列
