# %% [markdown]
# # The Staack Abstract Data Type (3.2)

# %% [markdown]
# ## Stack

# %% [raw]
# 1. 是一個有順序的list(ordered list)
# 2. 有下列功能
# insertions(additions、pushes)
# deletions(removals、pops)
# 3. 具有「Last-In-First-Out」的資料結構(可以想像成一種裝資料的容器)，「最晚進入Stack」的資料會「最先被取出」，「最早進入Stack」的資料則「最晚被取出」。
#
# 4.Stack是一個抽象的概念，只要符合「Last-In-First-Out」(LIFO)的資料結構，都可以視為Stack。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Stack Operations

# %% [raw]
# 就像搬家的時候要把書(資料)裝進箱子(Stack)，假設箱子的開口大小剛剛好只能平放一本書，如果先放入《灌籃高手》，再放《笑傲江湖》，再放《搶救國文大作戰》，那麼到了新家之後，因為箱子底下沒有破洞，所以要拿到最底下的《灌籃高手》，就一定得先把上面的《搶救國文大作戰》與《笑傲江湖》拿出箱子才行。
#
# 資料只能往上疊，取出也只能從上面開始拿。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Stack: ADT

# %% [markdown]
# ![image.png](attachment:image.png)
