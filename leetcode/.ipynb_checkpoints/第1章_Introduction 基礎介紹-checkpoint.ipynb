# %% [markdown]
# # introduction基礎介紹

# %% [raw]
# 需求：要達到的功能是什麼
# 分析：先巨觀來看 在微觀
# 設計：有什麼function？跟演算法有關係 設計一些演算法來達到function的目的
# Coding & refinement: 寫code 修改 優化
# 驗證: 測試，看結果對不對 用不同case測試 除正確性，有效性也要看，資料量大時 速度差別？ 效率好不好等等。error code寫在文件上，commit，講程式在幹嘛 交接比較好
#
# 資料結構：用特定的方法來儲存、組織資料，使得這些資料能更有效率地被使用。
# EX:
# B-Tree用於databases application，使資料平衡，不會有搜尋效率很差的現象。
# Hash table(雜湊對應表)：在編輯器裡能有效地找出對應identifier識別尺，能知道這個字詞是否有被用過，除岑在哪裡。

# %% [markdown]
# ## 程式評估方法 evaluative judgments about programs
#      Meet the original specification? : code是否合乎預期
#      Work correctly?
#      Document?
#      Use functions to create logical units?
#      Code readable?
#      Use storage efficiently?
#      Running time acceptable?

# %% [markdown]
# ## 資料抽象化&演算法規範

# %% [raw]
# 演算法開發：sudo code再來寫程式
#
# 程式=資料結構+演算法
# 演算法：用電腦解決問題的步驟
# 定義：完成特定功能的有限指令
# 特性
# 輸入性(Input)：0或1個以上的輸入
# 輸出性(Output)：1個以上的輸出
# 明確性(Definiteness)：每個指令需清楚，不能模稜兩可
# 有限性(Finteness)：在執行有限步驟後結束
# 演算法需滿足有限性，但程式不一定滿足有限性
# 有效性(Effectiveness)：可用紙筆追蹤
#
# Abstract data types (ADT's) should be implementation independent. 分隔 data type 與 implementation 增加以後調整的彈性和自由。
#
# 若為implementation dependent, 則需copy記憶體位置

# %% [markdown]
# ## 選擇排序法 Selection sort

# %% [raw]
# 簡介：一串數字，選出最小的數字排列，最後回傳排好順序的一串數字。
# 解法：將數字分成set(排好順序)、unset(沒排順序)；找最小的數跟最前面的數字SWAP交換。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 二元排序法Binary Sort

# %% [raw]
# binary search的前提是必須先排好序。
# binary search可以使用迭代或者遞迴的方式來尋找。
#
# 目的：從排好序的數字中找出某數字的位置。
# 最笨naive的方法：一個一個找
# Binary search二分法：1.要先依大小排 2.將全部數列切一半 3.再切含此數字的那一半
# Hash: 也可用來找數字

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 選擇問題(selection problem) & 遞迴演算法

# %% [markdown]
# ### selection problem:從N個數字裡找到第K大的數字。

# %% [raw]
# 找第k大的值》方法一：Naive method:1.放到array 2.依大小排序 3.取出第k大的值
# 找第k大的值》方法二：從n個數中選k個數出來，依大小排序建成array，再從剩餘沒被選中的數中一個一個來跟array中最大的數比，比他大就留著，比他小就丟掉。
# (如果N遠大於K的話，這個方法的效率會好很多，因為排序的次數小很多)
#
# 透過sorting的方法去解selection problem

# %% [markdown]
# ### Recursive Algorithms(呼叫自己的function)

# %% [raw]
# Recursive algorithm: 自己呼叫自己，如C(n,m)
# Boundary recursive: 能停止的自己呼叫自己的function

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Boundary condition: b=1時，程式結束。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 遞迴演算法 & 遞迴二元搜尋

# %% [raw]
# direct recursive(呼叫別的recursive function) vs indirect recursive(自己recursive)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 遞迴排列(Recursive permutations)

# %% [raw]
# Recursive permutations: 把a固定住，其他排列組合，以此類推

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 效能評估 & 空間複雜度

# %% [raw]
# Performance Analysis:
#     complexity theory
#     space complexity: amount of memory
#     time complexity: amount of computer time

# %% [markdown]
# ### 空間複雜度(space complexity)

# %% [raw]
# S(P) = c + Sp(I)
# S(P): 這個program所占空間
# c: const，存放空間等等(比較不重要因為是較固定的資源消耗)
# Sp(I): Space complexity with a particular input I. 跟隨著不同的 input I 所站的空間大小會不同。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 時間複雜度time complexity

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# 為何float tempsum要count, 而int i不用？
# 因int i沒有assignment ，有assignment 才算作"運算"
# 只有宣告，沒有assignment不算運算

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Tabular method

# %% [raw]
# s/e(assignment) * freq = total step

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# n^2+2n vs 10n，10n的效率較好

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### asymptotic Notation -BIG O

# %% [raw]
# Big-Ο代表演算法時間函式的上限(Upper bound)最壞的狀況下，演算法執行時間不會超過Big-Ο
# 格式：f(n) = Ο(g(n)) iff ∃正常數c和n0，使得f(n) ≤ c × g(n), ∀ n >= n0
# n--輸入資料大小
# f(n)--理想狀況下，程式在電腦中實際執行指令次數
# g(n)--執行時間的成長率

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### asymptotic Notation -Omega

# %% [raw]
# Ω代表演算法時間函式的下限(Lower bound)在最好狀況下，演算法執行時間不會比Omega快
# 格式：f(n) = Ω(g(n)) iff ∃正常數c和n0，使得f(n) ≥ c × g(n), ∀ n >= n0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### asymptotic Notation -Theta

# %% [raw]
# Θ代表演算法時間函式的上限與下限
# 格式：f(n) = Θ(g(n)) iff ∃正常數c1,c2和n0，使得c1 × g(n) ≤ f(n) ≤ c2 × g(n) , ∀ n ≥ n0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Big O與Omega都是用來分析程式的complexity
#
# 假設有兩個模組T1、T2
# Rule 1:
# (a)先T1執行，完成後在執行T2：分開呼叫：取maximum 複雜度
# (b)T1中呼叫T2：兩複雜度相乘
#
# Rule 2:
# 若一個多項式由k構成，其複雜度為N^k

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 練習

# %% [raw]
# 每一次迴圈都要執行3個指令

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# 1個迴圈=N

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# 1. 程式有兩個區塊，先執行第一個，在執行第二個，所以複雜度要取這兩個的最大

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
